# %%
# Libraries
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.style.use("ggplot")
# %matplotlib inline
matplotlib.rcParams["figure.figsize"] = (12, 8)

# %%
# Reading csv file
df = pd.read_csv(r"C:\Users\tomi0\Downloads\movies.csv")

# %%
# Displaying the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
'''Data Cleaning 
'''
# Checking for missing data
for i in df.columns:
    missing_perc = np.mean(df[i].isnull())
    print("{} - {}%".format(i, missing_perc))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# There were missing data so we discard them
df.dropna(inplace=True)

# %%
# Checking again for missing data
for i in df.columns:
    missing_perc = np.mean(df[i].isnull())
    print("{} - {}%".format(i, missing_perc))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Checking the data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data types as required
df["budget"] = df["budget"].astype("int64")
df["gross"] = df["gross"].astype("int64")

# %%
# Looking at new changes to data types
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Matching year to date released
df['year_fix'] = df['released'].str.extract(r'(\d{4})')

# %%
df = df.sort_values(by=["gross"], inplace=False, ascending=False)

# %%
# Checking for and removing duplicates
df = df.drop_duplicates()

df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
'''Investigating correlations'''
# Scatter plot of budget w.r.t. gross
plt.scatter(x=df["budget"], y=df["gross"])
plt.title("Budget vs Revenue")
plt.xlabel("Revenue")
plt.ylabel("Film Budget")
plt.show()

# %%
# From scatter plot above the variables seem to be correlated

# Using seaborn for better visualisation of correlation
sns.regplot(x="budget", y="gross", data=df, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Looking at all correlation values
df.select_dtypes(include=[int, float]).corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# High correlation between gross and budget as expected

# %%
# Fixing the daata type of the year_fix column that was created as it didn't show up in correlation matrix
df["year_fix"] = df["year_fix"].astype("int64")

# %%
correlation_matrix = df.select_dtypes(include=[int, float]).corr()
# Checking if it now shows up
correlation_matrix
# Out:
#               year     score     votes    budget     gross   runtime  year_fix
# year      1.000000  0.061923  0.203098  0.320312  0.268721  0.075294  1.000000
# score     0.061923  1.000000  0.474256  0.072001  0.222556  0.414068  0.061923
# votes     0.203098  0.474256  1.000000  0.439675  0.614751  0.352303  0.203098
# budget    0.320312  0.072001  0.439675  1.000000  0.740247  0.318695  0.320312
# gross     0.268721  0.222556  0.614751  0.740247  1.000000  0.275796  0.268721
# runtime   0.075294  0.414068  0.352303  0.318695  0.275796  1.000000  0.075294
# year_fix  1.000000  0.061923  0.203098  0.320312  0.268721  0.075294  1.000000

# %%
# Copying over the year_fix to year and deleting it(rerunning the code in the cell above indicates it has been fixed)
df["year"] = df["year_fix"]
df = df.drop(columns=["year_fix"])
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2015
# 2434                  Philadelphia Experiment II      PG-13  Action  1994
# 3681                                Ginger Snaps  Not Rated   Drama  2001
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
correlation_matrix = df.select_dtypes(include=[int, float]).corr()

# Visualising the correlations
sns.heatmap(correlation_matrix, annot=True)

plt.title("Correlation Matrix between numeric attributes")
plt.xlabel("Film Attributes")
plt.ylabel("Film Attributes")
plt.show()

# %%
df_copy = df

for col in df_copy.columns:
    if(df_copy[col].dtype == "object"):
        df_copy[col] = df_copy[col].astype("category")
        df_copy[col] = df_copy[col].cat.codes

df_copy
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2015       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1994      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2001      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
correlation_matrix_copy = df_copy.corr()

# Visualising the correlations from df_copy (accounting for non-numeric values)
sns.heatmap(correlation_matrix_copy, annot=True)

plt.title("Correlation Matrix between film attributes")
plt.xlabel("Film Attributes")
plt.ylabel("Film Attributes")
plt.show()

# %%
correlation_matrix_copy
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.022021  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.069147  0.022142  0.035106
# year      0.025542  0.022021 -0.069147  1.000000 -0.005989  0.061923
# released -0.006152  0.018083  0.022142 -0.005989  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.061923  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.203098  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.037371  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025495  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032687  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.073569 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.320312  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.268721  0.008501  0.222556
# ...

# %%
correlation_pairs = correlation_matrix_copy.unstack()
correlation_pairs
# Out:
# name     name        1.000000
#          rating     -0.029234
#          genre       0.010996
#          year        0.025542
#          released   -0.006152
#                        ...
# runtime  country    -0.034477
#          budget      0.318695
#          gross       0.275796
#          company     0.037585
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = correlation_pairs.sort_values()
sorted_pairs
# Out:
# budget   genre     -0.368523
# genre    budget    -0.368523
# gross    genre     -0.244101
# genre    gross     -0.244101
# budget   rating    -0.203946
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
# Checking for attributes with high correlation
high_correlation = sorted_pairs[(sorted_pairs) > 0.5]

high_correlation
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
# New finding: Gross and votes are highly correlated
# Unexpected: The company name is not highly correlated with gross or revenue

'''End of project'''
# Out:
# 'End of project'
